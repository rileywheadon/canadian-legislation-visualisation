# %% [markdown]
# ## Havoc on the Hill -- A Visualisation of Canadian Legislation Since 1994
# By Riley Wheadon
# January 2nd, 2023
# ---

# %%
# Import Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read .json file
data = pd.read_json('../data/raw/bills.json')

# Display first three rows of the dataframe
display(data.head(3))
# Out:
#          Id NumberCode  NumberPrefix  Number                  LongTitleEn  \
# 0  11473483        S-1           NaN       0  An Act relating to railways
# 1  10867804        S-1           NaN       0  An Act relating to railways
# 2  10601138        S-1           NaN       0  An Act relating to railways
#
#                          LongTitleFr                    LongTitle  \
# 0  Loi concernant les chemins de fer  An Act relating to railways
# 1  Loi concernant les chemins de fer  An Act relating to railways
# 2  Loi concernant les chemins de fer  An Act relating to railways
#
#   ShortTitleEn ShortTitleFr ShortTitle  ...  HouseVoteDetails  \
# 0                                       ...               NaN
# 1                                       ...               NaN
# 2                                       ...               NaN
#
#   SenateVoteDetails HouseRulingAndStatements SenateRulingAndStatements  \
# 0               NaN                      NaN                       NaN
# 1               NaN                      NaN                       NaN
# 2               NaN                      NaN                       NaN
#
#    WebReferences BibliographicNotices SenatePreStudyCommitteeDetails  \
# 0            NaN                  NaN                            NaN
# 1            NaN                  NaN                            NaN
# 2            NaN                  NaN                            NaN
#
#   SimilarBills IsDroppedFromSenateOrderPaper  IsSessionOngoing
# 0          NaN                         False              True
# 1          NaN                         False             False
# 2          NaN                         False             False
#
# [3 rows x 135 columns]

# %%
# Create helper function to print missing values by column
def printNull(df):
    output = "\n".join([
        "-----------", 
        "{shape}",
        "-----------",
        "{missing}"
    ]).format(
        shape = df.shape, 
        missing = df.isna().sum().to_string()
    )
    print(output)

# Print data shape, column names, and missing values
printNull(data)
# Out:
# -----------
# (6761, 135)
# -----------
# Id                                                   0
# NumberCode                                           0
# NumberPrefix                                      6761
# Number                                               0
# LongTitleEn                                          0
# LongTitleFr                                          0
# LongTitle                                            0
# ShortTitleEn                                         0
# ShortTitleFr                                         0
# ShortTitle                                           0
# StatusId                                          6761
# StatusNameEn                                         0
# StatusNameFr                                         0
# StatusName                                           0
# LatestCompletedMajorStageId                          0
# LatestCompletedMajorStageNameEn                      0
# LatestCompletedMajorStageNameFr                      0
# LatestCompletedMajorStageName                        0
# LatestCompletedMajorStageNameWithChamberSuffix       0
# IsInSenatePreStudy                                   0
# LatestCompletedMajorStageChamberOrganizationId       0
# LatestCompletedMajorStageChamberNameEn            6761
# LatestCompletedMajorStageChamberNameFr            6761
# LatestCompletedMajorStageChamberName              6761
# OngoingStageId                                       0
# OngoingStageNameEn                                6761
# OngoingStageNameFr                                6761
# OngoingStageName                                  6761
# LatestCompletedBillStageId                           0
# LatestCompletedBillStageNameEn                    6761
# LatestCompletedBillStageNameFr                    6761
# LatestCompletedBillStageName                      6761
# LatestCompletedBillStageChamberOrganizationId        0
# LatestCompletedBillStageChamberNameEn             6761
# LatestCompletedBillStageChamberNameFr             6761
# LatestCompletedBillStageChamberName               6761
# LatestCompletedBillStageDateTime                  6761
# ParliamentNumber                                     0
# SessionNumber                                        0
# BillDocumentTypeId                                   0
# BillDocumentTypeNameEn                               0
# BillDocumentTypeNameFr                               0
# BillDocumentTypeName                                 0
# IsGovernmentBill                                     0
# OriginatingChamberOrganizationId                     0
# OriginatingChamberNameEn                          6761
# OriginatingChamberNameFr                          6761
# OriginatingChamberName                            6761
# IsHouseBill                                          0
# IsSenateBill                                         0
# SponsorSenateSystemAffiliationId                  6761
# SponsorPersonId                                   6761
# SponsorPersonOfficialFirstName                    6761
# SponsorPersonOfficialLastName                     6761
# SponsorPersonUsualFirstName                       6761
# SponsorPersonMiddleName                           6761
# SponsorPersonName                                    0
# SponsorPersonShortHonorificEn                     6761
# SponsorPersonShortHonorificFr                     6761
# SponsorPersonShortHonorific                       6761
# SponsorAffiliationTitleEn                         6761
# SponsorAffiliationTitleFr                         6761
# SponsorAffiliationTitle                           6761
# SponsorAffiliationRoleId                          6761
# SponsorAffiliationRoleNameEn                      6761
# SponsorAffiliationRoleNameFr                      6761
# SponsorAffiliationRoleName                        6761
# SponsorConstituencyId                             6761
# SponsorConstituencyNameEn                         6761
# SponsorConstituencyNameFr                         6761
# SponsorConstituencyName                           6761
# LatestBillEventEventTypeId                           0
# LatestBillEventTypeNameEn                         6761
# LatestBillEventTypeNameFr                         6761
# LatestBillEventStageId                            6761
# LatestBillEventTypeName                           6761
# LatestBillEventCommitteeDetails                   6761
# LatestBillEventDateTime                              0
# LatestBillEventChamberOrganizationId                 0
# LatestBillEventChamberNameEn                      6761
# LatestBillEventChamberNameFr                      6761
# LatestBillEventChamberName                        6761
# LatestBillEventNumberOfAmendments                    0
# LatestBillEventAmendmentNoteId                       0
# LatestBillEventMeetingNumber                      6761
# LatestBillEventAdditionalInformationEn            6761
# LatestBillEventAdditionalInformationFr            6761
# LatestBillEventAdditionalInformation              6761
# PassedHouseFirstReadingDateTime                   1564
# PassedHouseSecondReadingDateTime                  5364
# PassedHouseThirdReadingDateTime                   5669
# PassedSenateFirstReadingDateTime                  5082
# PassedSenateSecondReadingDateTime                 5439
# PassedSenateThirdReadingDateTime                  5667
# ReceivedRoyalAssentDateTime                       5777
# DidReinstateFromPreviousSession                      0
# ReinstatedFromBillDocumentId                      6761
# ReinstatedFromBillNumberCode                      6761
# DidReinstateInNextSession                            0
# ReinstatedAsBillDocumentId                        6761
# ReinstatedAsBillNumberCode                        6761
# PassedFirstChamberFirstReading                       0
# PassedFirstChamberSecondReading                      0
# PassedFirstChamberThirdReading                       0
# PassedSecondChamberFirstReading                      0
# PassedSecondChamberSecondReading                     0
# PassedSecondChamberThirdReading                      0
# ReceivedRoyalAssent                                  0
# ConsideredDuringPreviousSitting                      0
# IsProForma                                           0
# BillFormId                                           0
# BillFormNameEn                                    6761
# BillFormNameFr                                    6761
# BillFormName                                      6761
# NotesEn                                           6761
# NotesFr                                           6761
# Notes                                             6761
# ShortLegislativeSummaryEn                         6761
# ShortLegislativeSummaryFr                         6761
# ShortLegislativeSummary                           6761
# IsFullLegislativeSummaryAvailable                    0
# StatuteYear                                       6761
# StatuteChapter                                    6761
# BillStages                                           0
# Publications                                      6761
# HouseVoteDetails                                  6761
# SenateVoteDetails                                 6761
# HouseRulingAndStatements                          6761
# SenateRulingAndStatements                         6761
# WebReferences                                     6761
# BibliographicNotices                              6761
# SenatePreStudyCommitteeDetails                    6761
# SimilarBills                                      6761
# IsDroppedFromSenateOrderPaper                        0
# IsSessionOngoing                                     0

# %% [markdown]
# As shown above, the dataset has a staggering **135** columns. However, multiple columns are missing all 6761 rows of data. We'll start by removing these columns. Additionally, some columns are redundant (i.e. duplicate information in French).
#
# ---

# %%
# Remove columns containing missing all values
data.dropna(axis = 1, how = 'all', inplace = True)

# Remove columns containing all zeros
data = data.loc[:, (data != 0).any(axis = 0)]

# Remove all columns that end in "En" or "Fr" to eliminate redundancies
data = data.loc[:, [col for col in data.columns if col[-2:] not in ("En", "Fr")]]

# Print information about new data after column removal
printNull(data)
# Out:
# -----------
# (6761, 34)
# -----------
# Id                                                   0
# NumberCode                                           0
# LongTitle                                            0
# ShortTitle                                           0
# StatusName                                           0
# LatestCompletedMajorStageId                          0
# LatestCompletedMajorStageName                        0
# LatestCompletedMajorStageNameWithChamberSuffix       0
# LatestCompletedMajorStageChamberOrganizationId       0
# ParliamentNumber                                     0
# SessionNumber                                        0
# BillDocumentTypeName                                 0
# OriginatingChamberOrganizationId                     0
# IsHouseBill                                          0
# IsSenateBill                                         0
# SponsorPersonName                                    0
# LatestBillEventDateTime                              0
# PassedHouseFirstReadingDateTime                   1564
# PassedHouseSecondReadingDateTime                  5364
# PassedHouseThirdReadingDateTime                   5669
# PassedSenateFirstReadingDateTime                  5082
# PassedSenateSecondReadingDateTime                 5439
# PassedSenateThirdReadingDateTime                  5667
# ReceivedRoyalAssentDateTime                       5777
# DidReinstateFromPreviousSession                      0
# PassedFirstChamberFirstReading                       0
# PassedFirstChamberSecondReading                      0
# PassedFirstChamberThirdReading                       0
# PassedSecondChamberFirstReading                      0
# PassedSecondChamberSecondReading                     0
# PassedSecondChamberThirdReading                      0
# ReceivedRoyalAssent                                  0
# BillStages                                           0
# IsSessionOngoing                                     0

# %% [markdown]
# It appears that the data contains groups of columns with binary data (i.e. PassedFirstChamberFirstReading and similar columns). These groups can be replaced with a single categorical column to improve clarity.

# %%
# Aggregate binary 'reading passed' columns into a single column
reading_columns = [col for col in data.columns if col[-7:] == "Reading"]
data["ReadingsPassed"]  = data[reading_columns].astype(int).sum(1)

# Aggregate IsHouseBill and IsSenateBill
data["BillOrigin"] = data[['IsHouseBill', 'IsSenateBill']].idxmax(1)

# Unify the title columns, with a preference for short titles where possible
data['ShortTitle'] = np.where(data['ShortTitle'] == '', data['LongTitle'], data['ShortTitle'])

# Drop initial aggregated columns
data.drop(columns = reading_columns + ['IsHouseBill', 'IsSenateBill', 'LongTitle'], inplace = True)

# Display all remaining columns
with pd.option_context('display.max_columns', None): 
    display(data.head(3))
# Out:
#          Id NumberCode                   ShortTitle  \
# 0  11473483        S-1  An Act relating to railways
# 1  10867804        S-1  An Act relating to railways
# 2  10601138        S-1  An Act relating to railways
#
#                      StatusName  LatestCompletedMajorStageId  \
# 0  Introduced as pro forma bill                        60043
# 1  Introduced as pro forma bill                        60043
# 2  Introduced as pro forma bill                        60043
#
#   LatestCompletedMajorStageName  \
# 0                 First reading
# 1                 First reading
# 2                 First reading
#
#   LatestCompletedMajorStageNameWithChamberSuffix  \
# 0                    First reading in the Senate
# 1                    First reading in the Senate
# 2                    First reading in the Senate
#
#    LatestCompletedMajorStageChamberOrganizationId  ParliamentNumber  \
# 0                                               2                44
# 1                                               2                43
# 2                                               2                43
#
#    SessionNumber BillDocumentTypeName  OriginatingChamberOrganizationId  \
# 0              1   Senate Public Bill                                 2
# 1              2   Senate Public Bill                                 2
# 2              1   Senate Public Bill                                 2
#
#   SponsorPersonName LatestBillEventDateTime PassedHouseFirstReadingDateTime  \
# 0                       0001-01-01T00:00:00                            None
# 1                       0001-01-01T00:00:00                            None
# 2                       0001-01-01T00:00:00                            None
#
#   PassedHouseSecondReadingDateTime PassedHouseThirdReadingDateTime  \
# 0                             None                            None
# 1                             None                            None
# 2                             None                            None
#
#   PassedSenateFirstReadingDateTime PassedSenateSecondReadingDateTime  \
# 0        2021-11-22T19:00:00-05:00                              None
# 1        2020-09-22T20:00:00-04:00                              None
# 2        2019-12-04T19:00:00-05:00                              None
#
#   PassedSenateThirdReadingDateTime ReceivedRoyalAssentDateTime  \
# 0                             None                        None
# 1                             None                        None
# 2                             None                        None
#
#    DidReinstateFromPreviousSession  ReceivedRoyalAssent  \
# 0                            False                False
# 1                            False                False
# 2                            False                False
#
#                                           BillStages  IsSessionOngoing  \
# 0  {'BillId': 0, 'HouseBillStages': [], 'SenateBi...              True
# 1  {'BillId': 0, 'HouseBillStages': [], 'SenateBi...             False
# 2  {'BillId': 0, 'HouseBillStages': [], 'SenateBi...             False
#
#    ReadingsPassed    BillOrigin
# 0               1  IsSenateBill
# 1               1  IsSenateBill
# 2               1  IsSenateBill

# %%
# There are still some more redundant columns, which will be removed manually
data.drop(
    columns = [
        'LatestCompletedMajorStageId', 'LatestCompletedMajorStageName', 'LatestCompletedMajorStageChamberOrganizationId',
        'LatestBillEventDateTime', 'OriginatingChamberOrganizationId', 'DidReinstateFromPreviousSession', 'BillStages', 
        'StatusName', 'SponsorPersonName'
    ], 
    inplace = True
)

# Rename some columns for clarity
data.rename(
    columns = {
        'NumberCode': 'Code',
        'ShortTitle': 'Title',
        'LatestCompletedMajorStageNameWithChamberSuffix': 'LatestStageName',
        'BillDocumentTypeName': 'BillType',
        'IsSessionOngoing': 'Ongoing'
    }, 
    inplace = True
)

# Display remaining columns
display(data.head(3))
# Out:
#          Id Code                        Title              LatestStageName  \
# 0  11473483  S-1  An Act relating to railways  First reading in the Senate
# 1  10867804  S-1  An Act relating to railways  First reading in the Senate
# 2  10601138  S-1  An Act relating to railways  First reading in the Senate
#
#    ParliamentNumber  SessionNumber            BillType  \
# 0                44              1  Senate Public Bill
# 1                43              2  Senate Public Bill
# 2                43              1  Senate Public Bill
#
#   PassedHouseFirstReadingDateTime PassedHouseSecondReadingDateTime  \
# 0                            None                             None
# 1                            None                             None
# 2                            None                             None
#
#   PassedHouseThirdReadingDateTime PassedSenateFirstReadingDateTime  \
# 0                            None        2021-11-22T19:00:00-05:00
# 1                            None        2020-09-22T20:00:00-04:00
# 2                            None        2019-12-04T19:00:00-05:00
#
#   PassedSenateSecondReadingDateTime PassedSenateThirdReadingDateTime  \
# 0                              None                             None
# 1                              None                             None
# 2                              None                             None
#
#   ReceivedRoyalAssentDateTime  ReceivedRoyalAssent  Ongoing  ReadingsPassed  \
# 0                        None                False     True               1
# 1                        None                False    False               1
# 2                        None                False    False               1
#
#      BillOrigin
# 0  IsSenateBill
# 1  IsSenateBill
# 2  IsSenateBill

# %%
# Get DateTime columns
datetime_columns = [col for col in data.columns if col[-8:] == "DateTime"]
data[datetime_columns] = data[datetime_columns].apply(lambda x: pd.to_datetime(x.str[:10]))

# Create new columns and calculate the amount of time the bill was debated
data["FirstStageDate"] = data[datetime_columns].min(axis = 1)
data["LastStageDate"] = data[datetime_columns].max(axis = 1)
data["TimeAlive"] = data["LastStageDate"] - data["FirstStageDate"]

# Drop original DateTime columns
data.drop(columns = datetime_columns, inplace = True)

# Replace Id column with a commonly used combination of parliament number, sesion number, and code
data["Id"] = data["ParliamentNumber"].astype(str) + "-" + data["SessionNumber"].astype(str) + "/" +  data["Code"] 

# Print remaining columns and check for null values
printNull(data)
display(data.head(3))
# Out:
# -----------
# (6761, 14)
# -----------
# Id                       0
# Code                     0
# Title                    0
# LatestStageName          0
# ParliamentNumber         0
# SessionNumber            0
# BillType                 0
# ReceivedRoyalAssent      0
# Ongoing                  0
# ReadingsPassed           0
# BillOrigin               0
# FirstStageDate         975
# LastStageDate          975
# TimeAlive              975
#          Id Code                        Title              LatestStageName  \
# 0  44-1/S-1  S-1  An Act relating to railways  First reading in the Senate
# 1  43-2/S-1  S-1  An Act relating to railways  First reading in the Senate
# 2  43-1/S-1  S-1  An Act relating to railways  First reading in the Senate
#
#    ParliamentNumber  SessionNumber            BillType  ReceivedRoyalAssent  \
# 0                44              1  Senate Public Bill                False
# 1                43              2  Senate Public Bill                False
# 2                43              1  Senate Public Bill                False
#
#    Ongoing  ReadingsPassed    BillOrigin FirstStageDate LastStageDate  \
# 0     True               1  IsSenateBill     2021-11-22    2021-11-22
# 1    False               1  IsSenateBill     2020-09-22    2020-09-22
# 2    False               1  IsSenateBill     2019-12-04    2019-12-04
#
#   TimeAlive
# 0    0 days
# 1    0 days
# 2    0 days

# %% [markdown]
# The data has been reduced down to a reasonable size, but there are still some issues. The PersonName column is filled with whitespace and there is no information on political affiliations of the various bills. Webscraping with beautifulsoup4 will be used to get additional data.
#
# ---

# %%
# Export cleaned data to a .csv file
data.to_csv('../data/processed/bills_processed.csv', index = False)
