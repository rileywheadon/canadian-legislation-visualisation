# %% [markdown]
# ## Creating the Data Set for Analysis
#
# This notebook aggregates data from three sources:
# - Cleaned bill data from https://www.parl.ca/legisinfo/en/bills?parlsession=all in 'data/cleaned_data.csv'
# - Bill info webscraped from the LEGISinfo database (https://www.parl.ca/legisinfo/en/bill/) in 'data/bill_info.csv'
# - Information on the members of parliament from https://www.ourcommons.ca/members/en/search?parliament=all&caucusId=all&province=all&gender=all in 'data/members_of_parliament.csv'

# %%
# Import Python libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bill = pd.read_csv('data/bill_info.csv')
mps = pd.read_csv('data/members_of_parliament.csv')
data = pd.read_csv('data/cleaned_data.csv')

# %% [markdown]
# ### Part 1a: Reformatting Bills Data

# %%
# Split bill_info objects into attributes
bill[['Id', 'Name', 'Title', 'Constituency']] = bill['SponsorInfo'].str.split('\n', 3, expand=True)
bill.drop(columns = ['SponsorInfo'], inplace = True)

for col in bill.columns:
    bill[col] = bill[col].apply(lambda x: x.split(':')[1].strip())
    
# Reformat names column to remove middle initials
def removeInitials(text):
    names = text.split(' ')
    names = [x for x in names if '.' not in x]
    return ' '.join(names)
        
bill['Name'] = bill['Name'].apply(lambda x: removeInitials(x))

# Rename columns to specify bill sponsorship
column_names = {
    'Name': 'SponsorName',
    'Title': 'SponsorTitle'
}

bill.rename(columns = column_names, inplace = True)

# %%
print(bill.shape)
display(bill.head())
# Out:
# (6761, 4)
#          Id      SponsorName                            SponsorTitle  \
# 0  44-1/S-1     Yuen Pau Woo                                 Senator
# 1  43-2/S-1        Marc Gold                                 Senator
# 2  43-1/S-1       Joseph Day                                 Senator
# 3  42-1/S-1     Yonah Martin                                 Senator
# 4  41-2/S-1  Claude Carignan  Leader of the Government in the Senate
#
#   Constituency
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %% [markdown]
# ### Part 1b: Reformatting MP Data

# %%
# Merge first and last name columns
mps['Name'] = mps['First Name'] + ' ' + mps['Last Name']

# Selecting only the political affiliation and namem columns
mps = mps[['Political Affiliation', 'Name']]

# %%
display(mps.head())
# Out:
#   Political Affiliation             Name
# 0          Conservative   Ziad Aboultaif
# 1          Conservative  Scott Aitchison
# 2          Conservative        Dan Albas
# 3               Liberal       John Aldag
# 4               Liberal    Omar Alghabra

# %% [markdown]
# ### Part 2: Merging Dataframes Together

# %%
# Merging bill and mps
bill = pd.merge(bill, mps, left_on = ['SponsorName'], right_on = ['Name'], how = 'left')

# %%
# Check for null values
# There is no data on senator affiliation so there will be some null values.

print(bill.isna().sum().to_string())
print(bill.shape)
display(bill)
# Out:
# Id                          0
# SponsorName                 0
# SponsorTitle                0
# Constituency                0
# Political Affiliation    1537
# Name                     1527
# (6763, 6)
#               Id      SponsorName                            SponsorTitle  \
# 0       44-1/S-1     Yuen Pau Woo                                 Senator
# 1       43-2/S-1        Marc Gold                                 Senator
# 2       43-1/S-1       Joseph Day                                 Senator
# 3       42-1/S-1     Yonah Martin                                 Senator
# 4       41-2/S-1  Claude Carignan  Leader of the Government in the Senate
# ...          ...              ...                                     ...
# 6758  41-2/C-699    Elizabeth May                    Member of Parliament
# 6759  41-2/C-700  Christine Moore                    Member of Parliament
# 6760  41-2/C-701     Irwin Cotler                    Member of Parliament
# 6761  41-2/C-702      Scott Simms                    Member of Parliament
# 6762  41-2/C-703      Scott Simms                    Member of Parliament
#
#                               Constituency Political Affiliation  \
# 0                                     None                   NaN
# 1                                     None                   NaN
# 2                                     None                   NaN
# 3                                     None                   NaN
# 4                                     None                   NaN
# ...                                    ...                   ...
# 6758                  Saanich—Gulf Islands           Green Party
# 6759                 Abitibi—Témiscamingue                   NDP
# 6760                           Mount Royal               Liberal
# 6761  Bonavista—Gander—Grand Falls—Windsor               Liberal
# 6762  Bonavista—Gander—Grand Falls—Windsor               Liberal
#
#                  Name
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 6758    Elizabeth May
# 6759  Christine Moore
# 6760     Irwin Cotler
# 6761      Scott Simms
# 6762      Scott Simms
#
# [6763 rows x 6 columns]

# %%
# Merge data and bill
data = pd.merge(data, bill, on = ['Id'], how = 'left')

# Drop redundant name column
data.drop(columns = 'Name', inplace = True)

# Replace NaN with None in political affiliation columns
data['Political Affiliation'].fillna(value = 'None', inplace = True)

# %%
print(data.isna().sum().to_string())
print(data.shape)
display(data.head(10))
# Out:
# Id                         0
# Code                       0
# Title                      0
# LatestStageName            0
# ParliamentNumber           0
# SessionNumber              0
# BillType                   0
# PersonName                 0
# ReceivedRoyalAssent        0
# Ongoing                    0
# ReadingsPassed             0
# BillOrigin                 0
# FirstStageDate           975
# LastStageDate            975
# TimeDebated              975
# SponsorName                0
# SponsorTitle               0
# Constituency               0
# Political Affiliation      0
# (6763, 19)
#          Id Code                        Title              LatestStageName  \
# 0  44-1/S-1  S-1  An Act relating to railways  First reading in the Senate
# 1  43-2/S-1  S-1  An Act relating to railways  First reading in the Senate
# 2  43-1/S-1  S-1  An Act relating to railways  First reading in the Senate
# 3  42-1/S-1  S-1  An Act relating to railways  First reading in the Senate
# 4  41-2/S-1  S-1  An Act relating to railways  First reading in the Senate
# 5  41-1/S-1  S-1  An Act relating to railways  First reading in the Senate
# 6  40-3/S-1  S-1  An Act relating to railways  First reading in the Senate
# 7  40-2/S-1  S-1  An Act relating to railways  First reading in the Senate
# 8  40-1/S-1  S-1  An Act relating to railways  First reading in the Senate
# 9  39-2/S-1  S-1  An Act relating to railways  First reading in the Senate
#
#    ParliamentNumber  SessionNumber                BillType PersonName  \
# 0                44              1      Senate Public Bill
# 1                43              2      Senate Public Bill
# 2                43              1      Senate Public Bill
# 3                42              1      Senate Public Bill
# 4                41              2  Senate Government Bill
# 5                41              1  Senate Government Bill
# 6                40              3  Senate Government Bill
# 7                40              2  Senate Government Bill
# 8                40              1  Senate Government Bill
# 9                39              2  Senate Government Bill
#
#    ReceivedRoyalAssent  Ongoing  ReadingsPassed BillOrigin FirstStageDate  \
# 0                False     True               1     Senate     2021-11-22
# 1                False    False               1     Senate     2020-09-22
# 2                False    False               1     Senate     2019-12-04
# 3                False    False               1     Senate     2015-12-03
# 4                False    False               1     Senate     2013-10-15
# 5                False    False               1     Senate     2011-06-02
# 6                False    False               1     Senate     2010-03-02
# 7                False    False               1     Senate     2009-01-25
# 8                False    False               1     Senate     2008-11-18
# 9                False    False               1     Senate     2007-10-15
#
#   LastStageDate TimeDebated      SponsorName  \
# 0    2021-11-22      0 days     Yuen Pau Woo
# 1    2020-09-22      0 days        Marc Gold
# 2    2019-12-04      0 days       Joseph Day
# 3    2015-12-03      0 days     Yonah Martin
# 4    2013-10-15      0 days  Claude Carignan
# 5    2011-06-02      0 days             None
# 6    2010-03-02      0 days             None
# 7    2009-01-25      0 days             None
# 8    2008-11-18      0 days             None
# 9    2007-10-15      0 days             None
#
#                              SponsorTitle Constituency Political Affiliation
# 0                                 Senator         None                  None
# 1                                 Senator         None                  None
# 2                                 Senator         None                  None
# 3                                 Senator         None                  None
# 4  Leader of the Government in the Senate         None                  None
# 5  Leader of the Government in the Senate         None                  None
# 6  Leader of the Government in the Senate         None                  None
# 7  Leader of the Government in the Senate         None                  None
# 8  Leader of the Government in the Senate         None                  None
# 9  Leader of the Government in the Senate         None                  None

# %%
# Export data for analysis
data.to_csv('data/final_data.csv', index = False)
